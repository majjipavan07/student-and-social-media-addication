# %% [markdown]
# # 📊 Student Social Media Addiction - Data Analysis Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')

# %%
df = pd.read_csv("Students Social Media Addiction.csv")

# %% [markdown]
# ### Query 1: First 5 rows

# %%
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %% [markdown]
# ### Query 2: DataFrame shape

# %%
df.shape
# Out:
# (705, 13)

# %% [markdown]
# ### Query 3: Column names

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Academic_Level', 'Country',
#        'Avg_Daily_Usage_Hours', 'Most_Used_Platform',
#        'Affects_Academic_Performance', 'Sleep_Hours_Per_Night',
#        'Mental_Health_Score', 'Relationship_Status',
#        'Conflicts_Over_Social_Media', 'Addicted_Score'],
#       dtype='object')

# %% [markdown]
# ### Query 4: Data types

# %%
df.dtypes
# Out:
# Student_ID                        int64
# Age                               int64
# Gender                           object
# Academic_Level                   object
# Country                          object
# Avg_Daily_Usage_Hours           float64
# Most_Used_Platform               object
# Affects_Academic_Performance     object
# Sleep_Hours_Per_Night           float64
# Mental_Health_Score               int64
# Relationship_Status              object
# Conflicts_Over_Social_Media       int64
# Addicted_Score                    int64
# dtype: object

# %% [markdown]
# ### Query 5: Missing values

# %%
df.isnull().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64

# %% [markdown]
# ### Query 6: Drop rows with missing values

# %%
df = df.dropna()

# %% [markdown]
# ### Query 7: Check for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Query 8: Drop duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Query 9: Summary statistics

# %%
df.describe()
# Out:
#        Student_ID         Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count  705.000000  705.000000             705.000000             705.000000
# mean   353.000000   20.659574               4.918723               6.868936
# std    203.660256    1.399217               1.257395               1.126848
# min      1.000000   18.000000               1.500000               3.800000
# 25%    177.000000   19.000000               4.100000               6.000000
# 50%    353.000000   21.000000               4.800000               6.900000
# 75%    529.000000   22.000000               5.800000               7.700000
# max    705.000000   24.000000               8.500000               9.600000
#
#        Mental_Health_Score  Conflicts_Over_Social_Media  Addicted_Score
# count           705.000000                   705.000000      705.000000
# mean              6.226950                     2.849645        6.436879
# ...

# %% [markdown]
# ### Query 10: Gender value counts

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    353
# Male      352
# Name: count, dtype: int64

# %% [markdown]
# ### Query 11: Pie chart - Gender Distribution

# %%
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title("Gender Distribution")
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Query 12: Bar plot - Most Used Platform

# %%
df['Most_Used_Platform'].value_counts().plot(kind='bar', color='orange')
plt.title("Most Used Social Media Platform")
plt.xlabel("Platform")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# ### Query 13: Histogram - Daily Usage Hours

# %%
df['Avg_Daily_Usage_Hours'].plot(kind='hist', bins=10, color='purple')
plt.title("Daily Social Media Usage (Hours)")
plt.xlabel("Hours")
plt.show()

# %% [markdown]
# ### Query 14: Convert Addiction Score to float

# %%
import pandas as pd
df['Addicted_Score'] = pd.to_numeric(df['Addicted_Score'], errors='coerce')
print(df['Addicted_Score'])
# Out:
# 0      8
# 1      3
# 2      9
# 3      4
# 4      7
#       ..
# 700    5
# 701    9
# 702    7
# 703    4
# 704    8
# Name: Addicted_Score, Length: 705, dtype: int64

# %% [markdown]
# ### Query 15: Heatmap of correlations (only numeric columns)

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Query 16: Average hours by gender

# %%
df.groupby('Gender')['Avg_Daily_Usage_Hours'].mean()
# Out:
# Gender
# Female    5.011048
# Male      4.826136
# Name: Avg_Daily_Usage_Hours, dtype: float64

# %% [markdown]
# ### Query 17: Count of students per academic level

# %%
df['Academic_Level'].value_counts()
# Out:
# Academic_Level
# Undergraduate    353
# Graduate         325
# High School       27
# Name: count, dtype: int64

# %% [markdown]
# ### Query 18: Average addiction score by platform

# %%
df.groupby('Most_Used_Platform')['Addicted_Score'].mean()
# Out:
# Most_Used_Platform
# Facebook     5.666667
# Instagram    6.554217
# KakaoTalk    6.000000
# LINE         3.000000
# LinkedIn     3.809524
# Snapchat     7.461538
# TikTok       7.428571
# Twitter      5.500000
# VKontakte    5.000000
# WeChat       6.066667
# WhatsApp     7.462963
# YouTube      6.100000
# Name: Addicted_Score, dtype: float64

# %% [markdown]
# ### Query 19: Students who spend more than 5 hours

# %%
df[df['Avg_Daily_Usage_Hours'] > 5]
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 2             3   20  Female  Undergraduate         USA
# 5             6   19  Female  Undergraduate   Australia
# 7             8   20  Female  Undergraduate      Brazil
# 11           12   20  Female  Undergraduate       Spain
# ..          ...  ...     ...            ...         ...
# 698         699   19  Female  Undergraduate      Canada
# 699         700   22    Male       Graduate          UK
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 2                      6.0             TikTok                          Yes
# ...

# %% [markdown]
# ### Query 20: Students with high addiction score (>7)

# %%
df[df['Addicted_Score'] > 7]
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 2             3   20  Female  Undergraduate         USA
# 5             6   19  Female  Undergraduate   Australia
# 7             8   20  Female  Undergraduate      Brazil
# 11           12   20  Female  Undergraduate       Spain
# ..          ...  ...     ...            ...         ...
# 694         695   20  Female  Undergraduate      Turkey
# 696         697   21  Female  Undergraduate      Mexico
# 699         700   22    Male       Graduate          UK
# 701         702   23    Male       Graduate      Russia
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 2                      6.0             TikTok                          Yes
# ...
